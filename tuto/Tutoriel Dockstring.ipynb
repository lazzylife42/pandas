# %% [markdown]
# # Pandas Basics
# ---

# %% [markdown]
# ## 01 Lire un CSV

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 02 Annalyser des données

# %%
df.head() # lit les 5 premières entrées, prend le nb en param
# Out:
#    id        date first_name   last_name                  email  gender  \
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 4   5  03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
#
#         ip_address        country price_paid   tax
# 0    160.119.8.119         Canada      $5.36   NaN
# 1   210.51.172.132         Canada      $8.32   NaN
# 2    213.8.101.145  United States      $3.73  20.0
# 3    5.140.237.101  United States      $3.70  20.0
# 4  106.252.162.233        Morocco      $9.24  20.0

# %%
df.tail() # lit les 5 dernières entrées, prend le nb en param
# Out:
#        id        date first_name last_name                       email  \
# 995   996  03/24/2021       Duff    Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame   Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty  Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito     Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle  Pringuer       rpringuerrr@house.gov
#
#      gender      ip_address        country price_paid   tax
# 995  Female  193.84.247.144         France      $3.63   NaN
# 996  Female  188.219.12.109            NaN      $4.59  20.0
# 997    Male    199.80.60.87  United States      $7.54  20.0
# 998    Male     0.183.63.11  United States      $5.81   NaN
# 999     NaN  170.193.249.83         Canada      $8.01  20.0

# %%
df.shape # renvoit un tuple avec le nb de rows et cols
# Out:
# (1000, 10)

# %%
df.columns # affiche les champs de l'objet, .tolist() pour en faire une list
# Out:
# Index(['id', 'date', 'first_name', 'last_name', 'email', 'gender',
#        'ip_address', 'country', 'price_paid', 'tax'],
#       dtype='object')

# %%
df.index # affiche les index de l'objet
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.set_index("email") # pour indexer avec un colonne, inplace=True pour écraser la variable
# Out:
#                               id        date first_name   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021    Marylin      Alders    Male
# hharridge1@gnu.org             2  03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021        Erl  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Grata      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021      Kanya     Beasant    Male
# ...                          ...         ...        ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021       Duff      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021        Ame     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021      Betty    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021    Paquito       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021   Rochelle    Pringuer     NaN
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 03 Sélectionner des données

# %%
df["email"].head() # pour recupérer les données d'une colonne
# Out:
# 0     malders0@shop-pro.jp
# 1       hharridge1@gnu.org
# 2    ekilminster2@etsy.com
# 3         gbrantl3@umn.edu
# 4      kbeasant4@jigsy.com
# Name: email, dtype: object

# %%
df.email.head() # marcher aussi si pas d'espace
# Out:
# 0     malders0@shop-pro.jp
# 1       hharridge1@gnu.org
# 2    ekilminster2@etsy.com
# 3         gbrantl3@umn.edu
# 4      kbeasant4@jigsy.com
# Name: email, dtype: object

# %%
type(df) # df est un tableau => DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.email) # df.email est une série => Series
# Out:
# pandas.core.series.Series

# %%
df[10:20] # pour prendre une partie des éléments, exclusif
# Out:
#     id        date first_name  last_name                       email  gender  \
# 10  11  03/11/2021       Lief  Woodcraft   lwoodcrafta@sitemeter.com    Male
# 11  12  03/16/2021     Bailie      Wyman            bwymanb@lulu.com    Male
# 12  13  03/05/2021     Janice   Morillas  jmorillasc@miibeian.gov.cn  Female
# 13  14  03/24/2021       Cull     Vassie          cvassied@unblog.fr     NaN
# 14  15  03/21/2021     Oralie     Maryon             omaryone@va.gov  Female
# 15  16  03/24/2021     Julina      Faint        jfaintf@amazon.co.jp  Female
# 16  17  03/27/2021        Eve    Allaway        eallawayg@ebay.co.uk  Female
# 17  18  03/20/2021       Esta    Boulden     ebouldenh@posterous.com     NaN
# 18  19  03/16/2021      Judye      Behan           jbehani@google.es  Female
# 19  20  03/01/2021     Sibeal     Mounch      smounchj@rakuten.co.jp    Male
#
#          ip_address        country price_paid   tax
# 10    201.76.240.51         Canada      $5.71   NaN
# ...

# %%
df.loc[10:13] # pareil mais inclusif
# Out:
#     id        date first_name  last_name                       email  gender  \
# 10  11  03/11/2021       Lief  Woodcraft   lwoodcrafta@sitemeter.com    Male
# 11  12  03/16/2021     Bailie      Wyman            bwymanb@lulu.com    Male
# 12  13  03/05/2021     Janice   Morillas  jmorillasc@miibeian.gov.cn  Female
# 13  14  03/24/2021       Cull     Vassie          cvassied@unblog.fr     NaN
#
#         ip_address        country price_paid   tax
# 10   201.76.240.51         Canada      $5.71   NaN
# 11  222.60.138.222  United States      $3.15  20.0
# 12   24.25.198.252         Canada      $5.30  20.0
# 13    18.203.61.94         France      $5.97  20.0

# %%
df_email = df.set_index("email")
df_email
# Out:
#                               id        date first_name   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021    Marylin      Alders    Male
# hharridge1@gnu.org             2  03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021        Erl  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Grata      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021      Kanya     Beasant    Male
# ...                          ...         ...        ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021       Duff      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021        Ame     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021      Betty    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021    Paquito       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021   Rochelle    Pringuer     NaN
#
# ...

# %%
df_email.loc['hharridge1@gnu.org'].values.tolist()
# pour récupérer les données et en faire un list
# Out:
# [np.int64(2),
#  '03/19/2021',
#  'Hinda',
#  'Harridge',
#  'Female',
#  '210.51.172.132',
#  'Canada',
#  '$8.32',
#  np.float64(nan)]

# %%
df_email.loc[['hharridge1@gnu.org', 'ekilminster2@etsy.com', 'ptesoerq@rakuten.co.jp']]
# Pour chercher plusieurs éléments
# Out:
#                          id        date first_name   last_name  gender  \
# email
# hharridge1@gnu.org        2  03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com     3  03/17/2021        Erl  Kilminster    Male
# ptesoerq@rakuten.co.jp  999  03/17/2021    Paquito       Tesoe    Male
#
#                             ip_address        country price_paid   tax
# email
# hharridge1@gnu.org      210.51.172.132         Canada      $8.32   NaN
# ekilminster2@etsy.com    213.8.101.145  United States      $3.73  20.0
# ptesoerq@rakuten.co.jp     0.183.63.11  United States      $5.81   NaN

# %%
df["gender"] == "Male"
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997     True
# 998     True
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df[df["gender"] == "Male"] # pour filtrer la df
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7      8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..   ...         ...        ...         ...                         ...
# 991  992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 992  993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#     gender       ip_address        country price_paid   tax
# ...

# %%
female_filter = df["gender"] == "Female"  # plus propre
df[female_filter]
# Out:
#       id        date first_name   last_name                       email  \
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 5      6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6      7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# 12    13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn
# ..   ...         ...        ...         ...                         ...
# 985  986  03/29/2021     Yvonne  Longworthy       ylongworthyrd@163.com
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996  997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
#
#      gender      ip_address        country price_paid   tax
# ...

# %%
country_filter = df["country"].isin(["France","Canada"]) 
df[country_filter]
# Out:
#        id        date first_name   last_name                      email  \
# 0       1  03/28/2021    Marylin      Alders       malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge         hharridge1@gnu.org
# 6       7  03/14/2021        Ava     Kencott         akencott6@phoca.cz
# 7       8  03/08/2021       Codi     Feasley           cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema      wheersema8@tumblr.com
# ..    ...         ...        ...         ...                        ...
# 992   993  03/04/2021    Maurene  Guilloneau     mguilloneaurk@about.me
# 993   994  03/22/2021      Ossie      Snelle           osnellerl@nhs.uk
# 994   995  03/17/2021   Carolyne    Bruntjen  cbruntjenrm@reference.com
# 995   996  03/24/2021       Duff      Errigo       derrigorn@elpais.com
# 999  1000  03/23/2021   Rochelle    Pringuer      rpringuerrr@house.gov
#
#      gender      ip_address country price_paid   tax
# ...

# %%
df_test =  df.copy()
df_test.price_paid = df_test.price_paid.apply(lambda x: x.replace("$", ""))
df_test.price_paid = df_test.price_paid.astype(float)
df_test[df_test["price_paid"] >= 5.0 ]
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 5       6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6       7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# ..    ...         ...        ...         ...                         ...
# 992   993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 04 Supprimer les colonnes

# %%
df1 = pd.read_csv("data.csv")

# %%
df1.drop("ip_address", axis=1, inplace=True)
df1.set_index("gender", inplace=True)

# %%
df1.drop("Male", axis=0, inplace=True)

# %%
df1.head()
# Out:
#         id        date first_name   last_name                       email  \
# gender
# Female   2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# Female   4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# Female   6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# Female   7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# Female  13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn
#
#               country price_paid   tax
# gender
# Female         Canada      $8.32   NaN
# Female  United States      $3.70  20.0
# Female  United States      $5.82   NaN
# Female         Canada      $6.29   NaN
# Female         Canada      $5.30  20.0

# %%
df1.drop(["first_name", "last_name", "email"], axis=1, inplace=True)
df1
# Out:
#           id        date        country price_paid   tax
# gender
# Female     2  03/19/2021         Canada      $8.32   NaN
# Female     4  03/19/2021  United States      $3.70  20.0
# Female     6  03/25/2021  United States      $5.82   NaN
# Female     7  03/14/2021         Canada      $6.29   NaN
# Female    13  03/05/2021         Canada      $5.30  20.0
# ...      ...         ...            ...        ...   ...
# NaN      990  03/16/2021         France      $8.69  20.0
# Female   995  03/17/2021         France      $5.68  20.0
# Female   996  03/24/2021         France      $3.63   NaN
# Female   997  03/17/2021            NaN      $4.59  20.0
# NaN     1000  03/23/2021         Canada      $8.01  20.0
#
# [562 rows x 5 columns]

# %%
del df1["id"] # autre méthode

# %%
df1
# Out:
#               date        country price_paid   tax
# gender
# Female  03/19/2021         Canada      $8.32   NaN
# Female  03/19/2021  United States      $3.70  20.0
# Female  03/25/2021  United States      $5.82   NaN
# Female  03/14/2021         Canada      $6.29   NaN
# Female  03/05/2021         Canada      $5.30  20.0
# ...            ...            ...        ...   ...
# NaN     03/16/2021         France      $8.69  20.0
# Female  03/17/2021         France      $5.68  20.0
# Female  03/24/2021         France      $3.63   NaN
# Female  03/17/2021            NaN      $4.59  20.0
# NaN     03/23/2021         Canada      $8.01  20.0
#
# [562 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 05 Traiter les valeurs manquantes

# %%
df = pd.read_csv("data.csv")
df.isnull() # pour voir si c'est NULL
# Out:
#         id   date  first_name  last_name  email  gender  ip_address  country  \
# 0    False  False       False      False  False   False       False    False
# 1    False  False       False      False  False   False       False    False
# 2    False  False       False      False  False   False       False    False
# 3    False  False       False      False  False   False       False    False
# 4    False  False       False      False  False   False       False    False
# ..     ...    ...         ...        ...    ...     ...         ...      ...
# 995  False  False       False      False  False   False       False    False
# 996  False  False       False      False  False   False       False     True
# 997  False  False       False      False  False   False       False    False
# 998  False  False       False      False  False   False       False    False
# 999  False  False       False      False  False    True       False    False
#
#      price_paid    tax
# ...

# %%
df.notnull()
# Out:
#        id  date  first_name  last_name  email  gender  ip_address  country  \
# 0    True  True        True       True   True    True        True     True
# 1    True  True        True       True   True    True        True     True
# 2    True  True        True       True   True    True        True     True
# 3    True  True        True       True   True    True        True     True
# 4    True  True        True       True   True    True        True     True
# ..    ...   ...         ...        ...    ...     ...         ...      ...
# 995  True  True        True       True   True    True        True     True
# 996  True  True        True       True   True    True        True    False
# 997  True  True        True       True   True    True        True     True
# 998  True  True        True       True   True    True        True     True
# 999  True  True        True       True   True   False        True     True
#
#      price_paid    tax
# 0          True  False
# ...

# %%
df[df["tax"].notnull()] # utiliser la func pour filtrer
# Out:
#        id        date first_name   last_name                       email  \
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7       8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..    ...         ...        ...         ...                         ...
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df["tax"].fillna(0) # pour fill les NULL
# Out:
# 0       0.0
# 1       0.0
# 2      20.0
# 3      20.0
# 4      20.0
#        ...
# 995     0.0
# 996    20.0
# 997    20.0
# 998     0.0
# 999    20.0
# Name: tax, Length: 1000, dtype: float64

# %%
df.dropna() # enlève tout ce qui est NULL
# Out:
#       id        date first_name   last_name                       email  \
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7      8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..   ...         ...        ...         ...                         ...
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 990  991  03/19/2021       Shep    Thorburn  sthorburnri@prnewswire.com
# 991  992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df.dropna(subset=["tax"], inplace=True) # pour spécifier la cible
df
# Out:
#        id        date first_name   last_name                       email  \
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7       8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..    ...         ...        ...         ...                         ...
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %% [markdown]
# ---
# ## 06 Ajouter des colonnes

# %%
df = pd.read_csv("data.csv")

# %%
df["tax"] = df["tax"].fillna(0)
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df.dtypes
# Out:
# id              int64
# date           object
# first_name     object
# last_name      object
# email          object
# gender         object
# ip_address     object
# country        object
# price_paid     object
# tax           float64
# dtype: object

# %%
# ici on convertis pour faire des calcules avec le même type

df.price_paid = df.price_paid.apply(lambda x: x.replace("$", ""))
df.price_paid = df.price_paid.astype(float)

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %%
df.dtypes
# Out:
# id              int64
# date           object
# first_name     object
# last_name      object
# email          object
# gender         object
# ip_address     object
# country        object
# price_paid    float64
# tax           float64
# dtype: object

# %%
# On calcule le prix payé total
df["price_total"] = df["price_paid"] * (1 - df["tax"] / 100)

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax  price_total
# ...

# %%
# Ici on créer une colonne en mappant un dictionaire sur le bon champ

countries = {"United States" : "UN",
             "France" : "FR",
             "Canada" : "CA",
             "Moroco" : "MA"}

df["country_code"] = df["country"].map(countries)
df.head(10)
# Out:
#    id        date first_name   last_name                  email  gender  \
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 4   5  03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
# 5   6  03/25/2021      Titos  Braybrooke   tbraybrooke5@umn.edu  Female
# 6   7  03/14/2021        Ava     Kencott     akencott6@phoca.cz  Female
# 7   8  03/08/2021       Codi     Feasley       cfeasley7@ed.gov    Male
# 8   9  03/09/2021     Waylon    Heersema  wheersema8@tumblr.com    Male
# 9  10  03/23/2021  Guglielma      Gookes  ggookes9@amazon.co.uk    Male
#
#         ip_address        country  price_paid   tax  price_total country_code
# 0    160.119.8.119         Canada        5.36   0.0        5.360           CA
# ...

# %% [markdown]
# ---
# ## 07 Analyser les données

# %%
df = pd.read_csv("data.csv")
df.describe()   # Décrits le set ou la col
# Out:
#                 id    tax
# count  1000.000000  654.0
# mean    500.500000   20.0
# std     288.819436    0.0
# min       1.000000   20.0
# 25%     250.750000   20.0
# 50%     500.500000   20.0
# 75%     750.250000   20.0
# max    1000.000000   20.0

# %%
df["price_paid"].describe()
# Out:
# count      1000
# unique      528
# top       $3.73
# freq          8
# Name: price_paid, dtype: object

# %%
df.price_paid = df.price_paid.apply(lambda x: x.replace("$", ""))
df.price_paid = df.price_paid.astype(float)

# %%
# Moyenne
df["price_paid"].mean()
# Out:
# np.float64(6.461930000000001)

# %%
# Somme
df["price_paid"].sum()
# Out:
# np.float64(6461.93)

# %%
#  Min
df["price_paid"].min()
# Out:
# np.float64(3.0)

# %%
#  Max
df["price_paid"].max()
# Out:
# np.float64(10.0)

# %%
#  unique
df["country"].unique().tolist()
# Out:
# ['Canada', 'United States', 'Morocco', 'France', nan]

# %%
#  value_counts()
df["country"].value_counts()
# Out:
# country
# France           408
# United States    333
# Canada           161
# Morocco           54
# Name: count, dtype: int64

# %%
df["gender"].value_counts(normalize=True)
# Out:
# gender
# Female    0.529538
# Male      0.470462
# Name: proportion, dtype: float64

# %%
#  Permet de filtrer puis d'afficher les stats du groupe
df_filtered = df[["price_paid", "tax", "country"]]
result = df_filtered.groupby("country").sum()
result
# Out:
#                price_paid     tax
# country
# Canada            1017.45  2160.0
# France            2619.61  5100.0
# Morocco            362.97   780.0
# United States     2183.67  4520.0

# %%
result.mean()
# Out:
# price_paid    1545.925
# tax           3140.000
# dtype: float64

# %%
df.groupby("gender")["price_paid"].mean()
# Out:
# gender
# Female    6.420406
# Male      6.469429
# Name: price_paid, dtype: float64

# %%
result = df.groupby(["gender", "country"])[["price_paid", "tax"]].mean()

# %%
result
# Out:
#                       price_paid   tax
# gender country
# Female Canada           6.419324  20.0
#        France           6.350352  20.0
#        Morocco          7.024815  20.0
#        United States    6.437118  20.0
# Male   Canada           6.117467  20.0
#        France           6.498950  20.0
#        Morocco          6.146957  20.0
#        United States    6.672500  20.0

# %% [markdown]
# ---

# %% [markdown]
# ## 08 Graphes

# %%
#  .plot() pour faire un graphe
df.groupby("date")["price_paid"].sum().plot(figsize=[7, 7])
# Out:
# <Axes: xlabel='date'>

# %%
# .pie() pour faire un camembert
df.groupby("gender")["price_paid"].sum().plot.pie(legend=True, figsize=(7,7))
# Out:
# <Axes: ylabel='price_paid'>

# %%
# .bar() pour les histogramme
df.groupby("country")["price_paid"].sum().plot.bar(rot=45, legend=True)
# Out:
# <Axes: xlabel='country'>
